# %%
import hls4ml

#Data Processing
import numpy as np
from numpy import loadtxt, expand_dims
import h5py
import sys

#ML model
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras.models import load_model


from sklearn.metrics import roc_curve
from sklearn.metrics import auc

#Plot settings
# %matplotlib inline
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.ROOT)

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

#line thickness
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 5

#Just to efficiently save plots
plot_dir = "../plot/"
print("Saving plot to: ", plot_dir)
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%d-%m-%Y")
save_path = plot_dir + dt_string
# Out:
# Saving plot to:  ../plot/

# %% [markdown]
# ## 1. Convert the model into firmware

# %%
keras_model = load_model('../saved_model/L1BTagModel_Flatten.h5')

# Create conversion config
yaml_config = {}
yaml_config['KerasModel'] = keras_model
yaml_config['OutputDir'] = 'L1B_test_4'
yaml_config['ProjectName'] = 'myproject'
yaml_config['XilinxPart'] = 'xcvu9p-flgb2104-2-i'
yaml_config['ClockPeriod'] = 5
yaml_config['IOType'] = 'io_parallel'
yaml_config['Backend'] = 'Vivado'

yaml_config['HLSConfig'] = {
'Model': {
'Precision': 'ap_fixed<16,8>',
'ReuseFactor': 10,
'Strategy': 'Resource'}}


hls_model = hls4ml.converters.keras_to_hls(yaml_config)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1d_input, layer type: InputLayer, current shape: [[None, 140, 1]]
# Layer name: conv1d, layer type: Conv1D, current shape: [[None, 140, 1]]
# Layer name: conv1d_1, layer type: Conv1D, current shape: [[None, 10, 50]]
# Layer name: dense, layer type: Dense, current shape: [[None, 10, 50]]
# Layer name: dense_1, layer type: Dense, current shape: [[None, 50]]
# Layer name: dense_2, layer type: Dense, current shape: [[None, 10]]
# Creating HLS model
# WARNING: Invalid ReuseFactor=10 with "Resource" strategy in layer "conv1d". Using ReuseFactor=7 instead. Valid ReuseFactor(s): 2,7,14,28,70,140,350,700.

# %%
hls_model.compile()
# Out:
# Writing HLS project
# Done
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-20374fcfe547> in <module>
# ----> 1 hls_model.compile()
#
# /data/dhoang/miniconda3/envs/b_tag/lib/python3.6/site-packages/hls4ml/model/hls_model.py in compile(self)
#     532                 dlclose_func.restype = ctypes.c_int
#     533                 dlclose_func(self._top_function_lib._handle)
# --> 534             self._top_function_lib = ctypes.cdll.LoadLibrary(lib_name)
#     535         finally:
#     536             os.chdir(curr_dir)
#
# /data/dhoang/miniconda3/envs/b_tag/lib/python3.6/ctypes/__init__.py in LoadLibrary(self, name)
#     424
#     425     def LoadLibrary(self, name):
# --> 426         return self._dlltype(name)
#     427
#     428 cdll = LibraryLoader(CDLL)
#
# /data/dhoang/miniconda3/envs/b_tag/lib/python3.6/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     346
#     347         if handle is None:
# --> 348             self._handle = _dlopen(self._name, mode)
#     349         else:
#     350             self._handle = handle
#
# OSError: firmware/myproject-82F099Ea.so: cannot open shared object file: No such file or directory

# %% [markdown]
# ## 2. Make the ROC curve

# %%
#Establish the input and output data for each dataset, expanding dimensions for compatability with Conv1D layer input
def load_testing_data(data_path):
    
    with h5py.File(data_path, 'r') as hf:
        dataset = hf["Testing Data"][:]

    X_test = dataset[:,0:len(dataset[0])-1]
    X_test = expand_dims(X_test, axis=2)
    y_test = dataset[:,len(dataset[0])-1]
    
    return X_test, y_test

X_test, y_test = load_testing_data('../data/testingDataver3.h5')

# %%
#Load in respective model for the datasets
model_1 = load_model('../saved_model/L1BTagModel_100GRU.h5')
model_2 = load_model('../saved_model/L1BTagModel_Flatten.h5')

#Creating ROC curves based on model predictions for each dataset
y_pred_1 = model_1.predict(X_test).ravel()
y_pred_2 = model_2.predict(X_test).ravel()
y_pred_3 = hls_model.predict(np.ascontiguousarray(X_test)).ravel()

fpr_1, tpr_1, thresholds_1 = roc_curve(y_test, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_test, y_pred_2)
fpr_3, tpr_3, thresholds_3 = roc_curve(y_test, y_pred_3)

auc_1 = auc(fpr_1, tpr_1)
auc_2 = auc(fpr_2, tpr_2)
auc_3 = auc(fpr_3, tpr_3)

# %%
#Create plot for ROC
plt.figure(1)
plt.plot([0,1],[0,1],'k--')

plt.plot(fpr_1, tpr_1, label='Conv1D_100GRU, AUC={:.3f}'.format(auc_1))
plt.plot(fpr_2, tpr_2, label='Conv1D_Flatten, AUC={:.3f}'.format(auc_2))
plt.plot(fpr_3, tpr_3, label='hls model, AUC={:.3f}'.format(auc_3))

#Establish labels and save image
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend(loc='best')

p_path = save_path + "Conv1D_100GRU_Flatten_hls.pdf"
print(p_path)
plt.savefig(p_path, bbox_inches='tight')
# Out:
# ../plot/20-05-2021Conv1D_100GRU_Flatten_hls.pdf
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# ## 3. build the model

# %%
hls_model.build(csim=False, reset = True)
# Out:
# Writing HLS project
# Done
# Synthesis report not found.
# {}

# %%
hls4ml.report.read_vivado_report('L1B_test_3/')
# Out:
# Found 1 solution(s) in L1B_test_2//myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Thu May 20 14:55:29 2021
#
# * Version:        2019.2.1 (Build 2724168 on Thu Dec 05 05:19:09 MST 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: virtexuplus
# * Target device:  xcvu9p-flgb2104-2-i
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 4.366 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+------+------+----------+
#     |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline |
#     |   min   |   max   |    min    |    max    |  min |  max |   Type   |
#     +---------+---------+-----------+-----------+------+------+----------+
#     |     8209|     8260| 41.045 us | 41.300 us |  7141|  8261| dataflow |
#     +---------+---------+-----------+-----------+------+------+----------+
#
#     + Detail:
#         * Instance:
#         +-----------------------------------------------------------+----------------------------------------------------------+---------+---------+-----------+-----------+------+------+----------+
#         |                                                           |                                                          |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline |
#         |                          Instance                         |                          Module                          |   min   |   max   |    min    |    max    |  min |  max |   Type   |
#         +-----------------------------------------------------------+----------------------------------------------------------+---------+---------+-----------+-----------+------+------+----------+
#         |dense_array_array_ap_fixed_16_8_5_3_0_50u_config6_U0       |dense_array_array_ap_fixed_16_8_5_3_0_50u_config6_s       |       25|       26|  0.125 us |  0.130 us |    25|    26|   none   |
#         |pointwise_conv_1d_cl_array_array_ap_fixed_50u_config12_U0  |pointwise_conv_1d_cl_array_array_ap_fixed_50u_config12_s  |      130|      130|  0.650 us |  0.650 us |   130|   130|   none   |
#         |conv_1d_cl_array_array_ap_fixed_50u_config2_U0             |conv_1d_cl_array_array_ap_fixed_50u_config2_s             |     7140|     8260| 35.700 us | 41.300 us |  7140|  8260|   none   |
#         |dense_array_array_ap_fixed_16_8_5_3_0_10u_config8_U0       |dense_array_array_ap_fixed_16_8_5_3_0_10u_config8_s       |       12|       13| 60.000 ns | 65.000 ns |    12|    13|   none   |
#         |relu_array_array_ap_fixed_50u_relu_config3_U0              |relu_array_array_ap_fixed_50u_relu_config3_s              |       12|       12| 60.000 ns | 60.000 ns |    12|    12|   none   |
#         |relu_array_array_ap_fixed_50u_relu_config5_U0              |relu_array_array_ap_fixed_50u_relu_config5_s              |       12|       12| 60.000 ns | 60.000 ns |    12|    12|   none   |
#         |relu_array_array_ap_fixed_50u_relu_config7_U0              |relu_array_array_ap_fixed_50u_relu_config7_s              |        0|        0|    0 ns   |    0 ns   |     1|     1| function |
#         |dense_array_array_ap_fixed_16_8_5_3_0_1u_config10_U0       |dense_array_array_ap_fixed_16_8_5_3_0_1u_config10_s       |       12|       13| 60.000 ns | 65.000 ns |    12|    13|   none   |
#         |relu_array_array_ap_fixed_10u_relu_config9_U0              |relu_array_array_ap_fixed_10u_relu_config9_s              |        0|        0|    0 ns   |    0 ns   |     1|     1| function |
#         |sigmoid_array_array_ap_fixed_1u_sigmoid_config11_U0        |sigmoid_array_array_ap_fixed_1u_sigmoid_config11_s        |        3|        3| 15.000 ns | 15.000 ns |     1|     1| function |
#         |Block_proc_U0                                              |Block_proc                                                |        0|        0|    0 ns   |    0 ns   |     0|     0|   none   |
#         +-----------------------------------------------------------+----------------------------------------------------------+---------+---------+-----------+-----------+------+------+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +---------------------+---------+-------+---------+---------+-----+
# |         Name        | BRAM_18K| DSP48E|    FF   |   LUT   | URAM|
# +---------------------+---------+-------+---------+---------+-----+
# |DSP                  |        -|      -|        -|        -|    -|
# |Expression           |        -|      -|        0|       20|    -|
# |FIFO                 |        0|      -|     1805|     9388|    -|
# |Instance             |     1180|   2901|    83247|   114783|    -|
# |Memory               |        -|      -|        -|        -|    -|
# |Multiplexer          |        -|      -|        -|       36|    -|
# |Register             |        -|      -|        6|        -|    -|
# +---------------------+---------+-------+---------+---------+-----+
# |Total                |     1180|   2901|    85058|   124227|    0|
# +---------------------+---------+-------+---------+---------+-----+
# |Available SLR        |     1440|   2280|   788160|   394080|  320|
# +---------------------+---------+-------+---------+---------+-----+
# |Utilization SLR (%)  |       81|    127|       10|       31|    0|
# +---------------------+---------+-------+---------+---------+-----+
# |Available            |     4320|   6840|  2364480|  1182240|  960|
# +---------------------+---------+-------+---------+---------+-----+
# |Utilization (%)      |       27|     42|        3|       10|    0|
# +---------------------+---------+-------+---------+---------+-----+
#
# + Detail:
#     * Instance:
#     +-----------------------------------------------------------+----------------------------------------------------------+---------+-------+-------+-------+-----+
#     |                          Instance                         |                          Module                          | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +-----------------------------------------------------------+----------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Block_proc_U0                                              |Block_proc                                                |        0|      0|      2|     11|    0|
#     |conv_1d_cl_array_array_ap_fixed_50u_config2_U0             |conv_1d_cl_array_array_ap_fixed_50u_config2_s             |       45|    100|   2402|  13481|    0|
#     |dense_array_array_ap_fixed_16_8_5_3_0_10u_config8_U0       |dense_array_array_ap_fixed_16_8_5_3_0_10u_config8_s       |       23|     50|   3540|   6204|    0|
#     |dense_array_array_ap_fixed_16_8_5_3_0_1u_config10_U0       |dense_array_array_ap_fixed_16_8_5_3_0_1u_config10_s       |        0|      1|    396|    497|    0|
#     |dense_array_array_ap_fixed_16_8_5_3_0_50u_config6_U0       |dense_array_array_ap_fixed_16_8_5_3_0_50u_config6_s       |     1111|   2500|  74446|  67387|    0|
#     |pointwise_conv_1d_cl_array_array_ap_fixed_50u_config12_U0  |pointwise_conv_1d_cl_array_array_ap_fixed_50u_config12_s  |        0|    250|   2426|  19287|    0|
#     |relu_array_array_ap_fixed_10u_relu_config9_U0              |relu_array_array_ap_fixed_10u_relu_config9_s              |        0|      0|      3|    494|    0|
#     |relu_array_array_ap_fixed_50u_relu_config3_U0              |relu_array_array_ap_fixed_50u_relu_config3_s              |        0|      0|     12|   2442|    0|
#     |relu_array_array_ap_fixed_50u_relu_config5_U0              |relu_array_array_ap_fixed_50u_relu_config5_s              |        0|      0|     12|   2442|    0|
#     |relu_array_array_ap_fixed_50u_relu_config7_U0              |relu_array_array_ap_fixed_50u_relu_config7_s              |        0|      0|      3|   2374|    0|
#     |sigmoid_array_array_ap_fixed_1u_sigmoid_config11_U0        |sigmoid_array_array_ap_fixed_1u_sigmoid_config11_s        |        1|      0|      5|    164|    0|
#     +-----------------------------------------------------------+----------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                                      |                                                          |     1180|   2901|  83247| 114783|    0|
#     +-----------------------------------------------------------+----------------------------------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# -----
