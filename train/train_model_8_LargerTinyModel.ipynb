# %% [markdown]
# # Train Keras model and make performance plots

# %%
#Data Processing
import numpy as np
from numpy import loadtxt, expand_dims
import h5py
import sys

#ML model
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense,Flatten, Dropout, Activation, concatenate, BatchNormalization, GRU, Add, Conv1D, Conv2D, Concatenate
from tensorflow.keras.models import Model, Sequential, load_model


from sklearn.metrics import roc_curve
from sklearn.metrics import auc

#Plot settings
# %matplotlib inline
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.ROOT)

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

#line thickness
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 5

#Just to efficiently save plots
plot_dir = "../plot/"
print("Saving plot to: ", plot_dir)
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%d-%m-%Y")
save_path = plot_dir + dt_string
# Out:
# Saving plot to:  ../plot/

# %% [markdown]
# ## 1. Train model

# %%
#Load in the datasets for training and compiling the sample weights
with h5py.File('../data/trainingDataver3.h5', 'r') as hf:
    dataset = hf["Training Data"][:]
with h5py.File('../data/sampleDataver3.h5', 'r') as hf:
    sampleData = hf["Sample Data"][:]
    

#Separate datasets into inputs and outputs, expand the dimensions of the inputs to be used with Conv1D layers
X = dataset[:,0:len(dataset[0])-1]
X = expand_dims(X, axis=2)
y = dataset[:,len(dataset[0])-1]

print("X shape: ", X.shape)
print("y shape: ", y.shape)

#Establish the sample weights
thebins = np.linspace(0, 200, 100)
bkgPts = []
sigPts = []
for i in range(len(sampleData)):
    if y[i]==1:
        sigPts.append(sampleData[i][0])
    if y[i]==0:
        bkgPts.append(sampleData[i][0])
bkg_counts, binsbkg = np.histogram(bkgPts, bins=thebins)
sig_counts, binssig = np.histogram(sigPts, bins=thebins)
a = []
for i in range(len(bkg_counts)):
    tempSig = float(sig_counts[i])
    tempBkg = float(bkg_counts[i])
    if tempBkg!=0:
        a.append(tempSig/tempBkg)
    if tempBkg==0:
        a.append(0)
        
#Normalize the sample weights above a certain pT
for i in range(42,len(a)):
    a[i]=0.7
    
#Add in the sample weights, 1-to-1 correspondence with training data
#Sample weight of all signal events being equal to 1
#Sample weight of all background events being equal to the sig/bkg ratio at that jet's pT
weights = []
for i in range(len(sampleData)):
    if y[i]==1:
        weights.append(1)
    if y[i]==0:
        jetPt = sampleData[i][0]
        tempPt = int(jetPt/2)
        if tempPt>98:
            tempPt = 98
        weights.append(a[tempPt])
# Out:
# X shape:  (200000, 140, 1)
# y shape:  (200000,)

# %%
#Define the model
model = Sequential()
model.add(Conv1D(filters=20, kernel_size=14, strides=14, activation='relu',input_shape=(len(dataset[0])-1,1)))
model.add(Conv1D(filters=5, kernel_size=1,activation='relu'))
model.add(Flatten())
model.add(Dense(30, activation = 'relu'))
model.add(Dense(15, activation = 'relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['binary_accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 10, 20)            300
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 10, 5)             105
# _________________________________________________________________
# flatten (Flatten)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 30)                1530
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 2,416
# Trainable params: 2,416
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the network
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', verbose=1, patience=5)

model.fit(X,y,
          epochs=50,
          batch_size=50,
          verbose=2,
          sample_weight=np.asarray(weights),
          validation_split=0.20,
          callbacks=[callback])
# Out:
# Epoch 1/50
# 3200/3200 - 9s - loss: 0.4578 - binary_accuracy: 0.6343 - val_loss: 0.4563 - val_binary_accuracy: 0.6123
# Epoch 2/50
# 3200/3200 - 7s - loss: 0.4503 - binary_accuracy: 0.6414 - val_loss: 0.4516 - val_binary_accuracy: 0.6437
# Epoch 3/50
# 3200/3200 - 6s - loss: 0.4483 - binary_accuracy: 0.6386 - val_loss: 0.4535 - val_binary_accuracy: 0.6546
# Epoch 4/50
# 3200/3200 - 7s - loss: 0.4458 - binary_accuracy: 0.6414 - val_loss: 0.4495 - val_binary_accuracy: 0.6294
# Epoch 5/50
# 3200/3200 - 7s - loss: 0.4426 - binary_accuracy: 0.6474 - val_loss: 0.4469 - val_binary_accuracy: 0.6353
# Epoch 6/50
# 3200/3200 - 7s - loss: 0.4393 - binary_accuracy: 0.6531 - val_loss: 0.4477 - val_binary_accuracy: 0.6636
# Epoch 7/50
# 3200/3200 - 7s - loss: 0.4373 - binary_accuracy: 0.6575 - val_loss: 0.4468 - val_binary_accuracy: 0.6498
# Epoch 8/50
# 3200/3200 - 6s - loss: 0.4358 - binary_accuracy: 0.6583 - val_loss: 0.4449 - val_binary_accuracy: 0.6704
# Epoch 9/50
# 3200/3200 - 6s - loss: 0.4341 - binary_accuracy: 0.6630 - val_loss: 0.4449 - val_binary_accuracy: 0.6468
# Epoch 10/50
# 3200/3200 - 7s - loss: 0.4330 - binary_accuracy: 0.6639 - val_loss: 0.4442 - val_binary_accuracy: 0.6551
# Epoch 11/50
# 3200/3200 - 6s - loss: 0.4320 - binary_accuracy: 0.6648 - val_loss: 0.4425 - val_binary_accuracy: 0.6481
# Epoch 12/50
# 3200/3200 - 7s - loss: 0.4302 - binary_accuracy: 0.6677 - val_loss: 0.4422 - val_binary_accuracy: 0.6583
# Epoch 13/50
# 3200/3200 - 7s - loss: 0.4284 - binary_accuracy: 0.6710 - val_loss: 0.4396 - val_binary_accuracy: 0.6674
# Epoch 14/50
# 3200/3200 - 7s - loss: 0.4271 - binary_accuracy: 0.6728 - val_loss: 0.4413 - val_binary_accuracy: 0.6583
# Epoch 15/50
# 3200/3200 - 7s - loss: 0.4263 - binary_accuracy: 0.6734 - val_loss: 0.4391 - val_binary_accuracy: 0.6571
# Epoch 16/50
# 3200/3200 - 7s - loss: 0.4248 - binary_accuracy: 0.6766 - val_loss: 0.4395 - val_binary_accuracy: 0.6588
# Epoch 17/50
# 3200/3200 - 7s - loss: 0.4239 - binary_accuracy: 0.6771 - val_loss: 0.4387 - val_binary_accuracy: 0.6728
# Epoch 18/50
# 3200/3200 - 6s - loss: 0.4231 - binary_accuracy: 0.6785 - val_loss: 0.4396 - val_binary_accuracy: 0.6491
# Epoch 19/50
# 3200/3200 - 6s - loss: 0.4221 - binary_accuracy: 0.6806 - val_loss: 0.4353 - val_binary_accuracy: 0.6672
# Epoch 20/50
# 3200/3200 - 7s - loss: 0.4211 - binary_accuracy: 0.6815 - val_loss: 0.4370 - val_binary_accuracy: 0.6709
# Epoch 21/50
# 3200/3200 - 6s - loss: 0.4199 - binary_accuracy: 0.6845 - val_loss: 0.4451 - val_binary_accuracy: 0.6302
# Epoch 22/50
# 3200/3200 - 7s - loss: 0.4192 - binary_accuracy: 0.6850 - val_loss: 0.4368 - val_binary_accuracy: 0.6510
# Epoch 23/50
# 3200/3200 - 6s - loss: 0.4183 - binary_accuracy: 0.6860 - val_loss: 0.4341 - val_binary_accuracy: 0.6536
# Epoch 24/50
# 3200/3200 - 6s - loss: 0.4174 - binary_accuracy: 0.6875 - val_loss: 0.4380 - val_binary_accuracy: 0.6308
# Epoch 25/50
# 3200/3200 - 7s - loss: 0.4169 - binary_accuracy: 0.6881 - val_loss: 0.4348 - val_binary_accuracy: 0.6788
# Epoch 26/50
# 3200/3200 - 6s - loss: 0.4161 - binary_accuracy: 0.6886 - val_loss: 0.4403 - val_binary_accuracy: 0.6823
# Epoch 27/50
# 3200/3200 - 6s - loss: 0.4152 - binary_accuracy: 0.6906 - val_loss: 0.4351 - val_binary_accuracy: 0.6552
# Epoch 28/50
# 3200/3200 - 6s - loss: 0.4147 - binary_accuracy: 0.6917 - val_loss: 0.4335 - val_binary_accuracy: 0.6758
# Epoch 29/50
# 3200/3200 - 6s - loss: 0.4141 - binary_accuracy: 0.6923 - val_loss: 0.4341 - val_binary_accuracy: 0.6903
# Epoch 30/50
# 3200/3200 - 6s - loss: 0.4131 - binary_accuracy: 0.6924 - val_loss: 0.4336 - val_binary_accuracy: 0.6786
# Epoch 31/50
# 3200/3200 - 6s - loss: 0.4126 - binary_accuracy: 0.6934 - val_loss: 0.4337 - val_binary_accuracy: 0.6790
# Epoch 32/50
# 3200/3200 - 7s - loss: 0.4121 - binary_accuracy: 0.6955 - val_loss: 0.4339 - val_binary_accuracy: 0.6702
# Epoch 33/50
# 3200/3200 - 7s - loss: 0.4117 - binary_accuracy: 0.6949 - val_loss: 0.4321 - val_binary_accuracy: 0.6678
# Epoch 34/50
# 3200/3200 - 7s - loss: 0.4113 - binary_accuracy: 0.6960 - val_loss: 0.4393 - val_binary_accuracy: 0.6932
# Epoch 35/50
# 3200/3200 - 6s - loss: 0.4106 - binary_accuracy: 0.6965 - val_loss: 0.4325 - val_binary_accuracy: 0.6630
# Epoch 36/50
# 3200/3200 - 7s - loss: 0.4102 - binary_accuracy: 0.6974 - val_loss: 0.4347 - val_binary_accuracy: 0.6687
# Epoch 37/50
# 3200/3200 - 6s - loss: 0.4100 - binary_accuracy: 0.6974 - val_loss: 0.4335 - val_binary_accuracy: 0.6855
# Epoch 38/50
# 3200/3200 - 7s - loss: 0.4094 - binary_accuracy: 0.6983 - val_loss: 0.4348 - val_binary_accuracy: 0.6708
# Epoch 00038: early stopping

# %%
model.save('../saved_model/L1BTagModel_Flatten_LargerTiny.h5')

# %% [markdown]
# ## 2. Make performance plot for the model

# %%
#Establish the input and output data for each dataset, expanding dimensions for compatability with Conv1D layer input
def load_testing_data(data_path):
    
    with h5py.File(data_path, 'r') as hf:
        dataset = hf["Testing Data"][:]
    X_test = dataset[:,0:len(dataset[0])-1]
    X_test = expand_dims(X_test, axis=2)
    y_test = dataset[:,len(dataset[0])-1]
    
    return X_test, y_test

X_test, y_test = load_testing_data('../data/testingDataver3.h5')

# %%
#Load in respective model for the datasets
model_1 = load_model('../saved_model/L1BTagModel_100GRU.h5')
model_2 = model

#Creating ROC curves based on model predictions for each dataset
y_pred_1 = model_1.predict(X_test).ravel()
y_pred_2 = model_2.predict(X_test).ravel()

fpr_1, tpr_1, thresholds_1 = roc_curve(y_test, y_pred_1)
fpr_2, tpr_2, thresholds_2 = roc_curve(y_test, y_pred_2)

auc_1 = auc(fpr_1, tpr_1)
auc_2 = auc(fpr_2, tpr_2)

# %%
#Create plot for ROC
plt.figure(1)
plt.plot([0,1],[0,1],'k--')

plt.plot(fpr_1, tpr_1, label='Conv1D 100GRU, AUC={:.3f}'.format(auc_1))
plt.plot(fpr_2, tpr_2, label='Tiny Conv1D Flatten, AUC={:.3f}'.format(auc_2))

#Establish labels and save image
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.legend(loc='best')

p_path = save_path + "LargerTinyConv1D_100GRU_Flatten.pdf"
print(p_path)
plt.savefig(p_path, bbox_inches='tight')
# Out:
# ../plot/31-05-2021LargerTinyConv1D_100GRU_Flatten.pdf
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
